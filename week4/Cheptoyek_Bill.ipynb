# %% [markdown]
# # Data analysis with pandas

# %%
import pandas as pd
import numpy as np

# %%
# SERIES
# 1.Write a Pandas program to compare the elements of two Pandas series. 
# Sample Series [4,65,436,3,9], [7,0,3,897,9]

series1 = pd.Series([5, 65, 436, 3, 9])
series2 = pd.Series([7, 0, 3, 897, 9])

result = series1 == series2
print(result)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
# 2.Write a Pandas program to add, subtract, multiply and divide two Pandas series. 

series3 = pd.Series([2, 4, 6, 8, 14])
series4 = pd.Series([1, 3, 5, 7, 9])
add_result = series3 + series4
subtract_result = series3 - series4
multiply_result = series3 * series4
divide_result = series3 / series4
print("\nAddition Result:")
print(add_result)
print("\nSubtraction Result:")
print(subtract_result)
print("\nMultiplication Result:")
print(multiply_result)
print("\nDivision Result:")
print(divide_result)
# Out:
# Addition Result:
# 0     3
# 1     7
# 2    11
# 3    15
# 4    23
# dtype: int64
#
# Subtraction Result:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    5
# dtype: int64
#
# Multiplication Result:
# 0      2
# 1     12
# 2     30
# 3     56
# 4    126
# dtype: int64
#
# Division Result:
# 0    2.000000
# 1    1.333333
# 2    1.200000
# 3    1.142857
# 4    1.555556
# dtype: float64

# %%
# 3.Write a Pandas program to convert a dictionary to a Pandas series. 
# Sample dictionary: dictionary1 = {‘Josh’: 24, ‘Sam’: 36, ‘Peace’: 19, ‘Charles’: 65, ‘Tom’: 44}

dictionary1 = {'Josh': 24, 'Sam': 36, 'Peace': 19, 'Charles': 65, 'Tom': 44}
series5 = pd.Series(dictionary1)
print("\nDictionary to Series Conversion:")
print(series5)
# Out:
# Dictionary to Series Conversion:
# Josh       24
# Sam        36
# Peace      19
# Charles    65
# Tom        44
# dtype: int64

# %%
# 4.Write a Pandas program to convert a given series to an array.
# Sample series: [‘Love’, 800, ‘Joy’, 789.9, ‘Peace’, True]

series6 = pd.Series(['Love', 800, 'Joy', 789.9, 'Peace', True])
array1 = np.array(series6)
print("\nSeries to Array Conversion:")
print(array1)
# Out:
# Series to Array Conversion:
# ['Love' 800 'Joy' 789.9 'Peace' True]

# %%
# Task 5: Find most frequent value and replace others with 'Other'
import pandas as pd

series7 = pd.Series(['Sudan', 'Ethiopia', 'Egypt', 'Egypt', 'Sudan', 'Egypt', 'Ethiopia', 'Egypt', 'Tunisia', 'Ethiopia',
                    'Ghana', 'Ghana', 'Ethiopia', 'Egypt', 'Egypt', 'Sudan', 'Egypt', 'Ghana', 'Tunisia', 'Senegal',
                    'Senegal', 'Ghana', 'Ivory Coast', 'Ghana', 'Senegal', 'Ghana', 'Ethiopia', 'Ivory Coast',
                    'Ethiopia', 'Algeria', 'Ivory Coast', 'Ethiopia', 'Ghana', 'Congo-Kinshasa', 'Senegal', 'Ghana',
                    'Congo-Kinshasa', 'Ghana', 'Ethiopia', 'Ghana', 'Ivory Coast', 'Congo-Kinshasa', 'Cameroon',
                    'Sudan', 'Cameroon', 'Ivory Coast', 'Ivory Coast', 'Sudan', 'Ghana', 'United Arab Rep.',
                    'Congo-Kinshasa', 'United Arab Rep.', 'Guinea', 'United Arab Rep.', 'Ivory Coast',
                    'United Arab Rep.', 'United Arab Rep.', 'Sudan', 'Cameroon', 'Mali', 'Mali', 'Cameroon', 'Togo',
                    'Cameroon', 'Congo', 'Zaire', 'Morocco', 'Zaire', 'Morocco', 'Congo', 'Cameroon', 'Zaire',
                    'Cameroon', 'Congo', 'Egypt', 'Zambia', 'Egypt', 'Ivory Coast', 'Egypt', 'Zambia', 'Zaire',
                    'Congo', 'Guinea', 'Congo', 'Congo', 'Zaire', 'Egypt', 'Congo', 'Congo', 'Zaire', 'Zaire',
                    'Ethiopia', 'Egypt', 'Egypt', 'Ethiopia', 'Guinea', 'Ethiopia', 'Nigeria', 'Morocco', 'Nigeria',
                    'Morocco', 'Morocco', 'Zaire', 'Guinea', 'Morocco', 'Morocco', 'Guinea', 'Nigeria', 'Guinea',
                    'Ghana', 'Nigeria', 'Zambia', 'Nigeria', 'Zambia', 'Ghana', 'Morocco', 'Uganda', 'Tunisia',
                    'Morocco', 'Congo', 'Uganda', 'Ghana', 'Uganda', 'Nigeria', 'Ghana', 'Nigeria', 'Egypt', 'Egypt',
                    'Nigeria', 'Ivory Coast', 'Nigeria', 'Ghana', 'Morocco', 'Algeria', 'Ghana', 'Algeria',
                    'Morocco', 'Nigeria', 'Algeria', 'Morocco', 'Nigeria', 'Libya', 'Cameroon', 'Cameroon', 'Libya',
                    'Ghana', 'Libya', 'Nigeria', 'Algeria', 'Zambia', 'Algeria', 'Algeria', 'Zambia', 'Ghana', 'Libya',
                    'Zambia', 'Ghana', 'Ivory Coast', 'Egypt', 'Cameroon', 'Ivory Coast', 'Egypt', 'Ivory Coast',
                    'Ghana', 'Algeria', 'Malawi', 'Algeria', 'Algeria', 'Ghana', 'Egypt', 'Algeria', 'Algeria',
                    'Cameroon', 'Senegal', 'Ivory Coast', 'Senegal', 'Egypt', 'Ivory Coast', 'Egypt', 'Algeria',
                    'Cameroon', 'Algeria', 'Cameroon', 'Morocco', 'Cameroon', 'Cameroon', 'Egypt', 'Ivory Coast',
                    'Egypt', 'Morocco', 'Ivory Coast', 'Ivory Coast', 'Morocco', 'Algeria', 'Morocco', 'Cameroon',
                    'Nigeria', 'Cameroon', 'Egypt', 'Cameroon', 'Nigeria', 'Nigeria', 'Morocco', 'Morocco',
                    'Cameroon', 'Algeria', 'Ivory Coast', 'Nigeria', 'Algeria', 'Nigeria', 'Algeria', 'Zambia',
                    'Senegal', 'Zambia', 'Senegal', 'Zambia', 'Cameroon', 'Zambia', 'Algeria', 'Zambia', 'Algeria',
                    'Nigeria', 'Nigeria', 'Senegal', 'Cameroon', 'Morocco', 'Cameroon', 'Ivory Coast', 'Ivory Coast',
                    'Algeria', 'Zambia', 'Ghana', 'Ghana', 'Nigeria', 'Cameroon', 'Ivory Coast', 'Ghana', 'Ghana',
                    'Cameroon', 'Nigeria', 'Ivory Coast', 'Tunisia', 'Mali', 'Tunisia', 'Nigeria', 'Egypt', 'Nigeria',
                    'Ivory Coast', 'Zambia', 'Zambia', 'Ghana', 'Senegal', 'Ghana', 'Zaire', 'Egypt', 'Zambia',
                    'Ghana', 'Nigeria', 'Zambia', 'Ivory Coast', 'Nigeria', 'South Africa', 'Egypt', 'Cameroon',
                    'South Africa', 'South Africa', 'Angola', 'Zambia', 'Sierra Leone', 'Algeria', 'Zambia',
                    'Algeria', 'Zambia', 'Gabon', 'Gabon', 'Zaire', 'Ghana', 'Tunisia', 'Ghana', 'Ivory Coast',
                    'Tunisia', 'Ghana', 'South Africa', 'Zambia', 'Gabon', 'Ghana', 'South Africa', 'Zambia',
                    'Ghana', 'South Africa', 'Burkina Faso', 'Algeria', 'Cameroon', 'Burkina Faso', 'Burkina Faso',
                    'Cameroon', 'DR Congo', 'Ghana', 'Tunisia', 'Togo', 'DR Congo', 'Tunisia', 'South Africa',
                    'Ivory Coast', 'Ivory Coast', 'Angola', 'Ivory Coast', 'South Africa', 'Morocco', 'Egypt',
                    'Egypt', 'Morocco', 'Zambia', 'Morocco', 'Cameroon', 'Tunisia', 'Ivory Coast', 'Morocco',
                    'DR Congo', 'Burkina Faso', 'DR Congo', 'South Africa', 'Ghana', 'Ivory Coast', 'Ghana',
                    'Cameroon', 'Ghana', 'Cameroon', 'South Africa', 'DR Congo', 'South Africa', 'Algeria',
                    'South Africa', 'DR Congo', 'Egypt', 'Burkina Faso', 'Egypt', 'Zambia', 'Egypt', 'Zambia',
                    'Nigeria', 'Morocco', 'Nigeria', 'Tunisia', 'Nigeria', 'Tunisia', 'Cameroon', 'South Africa',
                    'Egypt', 'Nigeria', 'Nigeria', 'Cameroon', 'South Africa', 'Nigeria', 'Mali', 'Algeria', 'Mali',
                    'Liberia', 'Mali', 'Liberia', 'South Africa', 'Morocco', 'South Africa', 'Burkina Faso',
                    'South Africa', 'Burkina Faso', 'Cameroon', 'Togo', 'Cameroon', 'DR Congo', 'Cameroon',
                    'DR Congo', 'Egypt', 'Zambia', 'Egypt', 'Senegal', 'Egypt', 'Senegal', 'South Africa', 'Nigeria',
                    'Cameroon', 'Senegal', 'Nigeria', 'Mali', 'Nigeria', 'Senegal', 'Tunisia', 'DR Congo', 'Rwanda',
                    'Tunisia', 'Tunisia', 'Rwanda', 'Kenya', 'Senegal', 'Senegal', 'Burkina Faso', 'Senegal',
                    'Burkina Faso', 'Zimbabwe', 'Cameroon', 'Cameroon', 'Algeria', 'Cameroon', 'Algeria', 'Nigeria',
                    'South Africa', 'Nigeria', 'Morocco', 'Morocco', 'Nigeria', 'Mali', 'Tunisia', 'Cameroon',
                    'Morocco', 'Tunisia', 'Morocco', 'Nigeria', 'Tunisia', 'Egypt', 'Morocco', 'Libya', 'Egypt',
                    'Egypt', 'Libya', 'Cameroon', 'Togo', 'Angola', 'Cameroon', 'Angola', 'Cameroon', 'Tunisia',
                    'South Africa', 'Zambia', 'Tunisia', 'Tunisia', 'Zambia', 'Nigeria', 'Zimbabwe', 'Ghana',
                    'Nigeria', 'Nigeria', 'Ghana', 'Guinea', 'Egypt', 'Nigeria', 'Cameroon', 'Egypt', 'Nigeria',
                    'Senegal', 'Egypt', 'Ghana', 'Namibia', 'Guinea', 'Ghana', 'Ghana', 'Guinea', 'Nigeria', 'Mali',
                    'Ivory Coast', 'Nigeria', 'Nigeria', 'Ivory Coast', 'Egypt', 'Sudan', 'Cameroon', 'Egypt',
                    'Cameroon', 'Egypt', 'Tunisia', 'South Africa', 'Senegal', 'Tunisia', 'Senegal', 'Tunisia',
                    'Ghana', 'Ivory Coast', 'Egypt', 'Tunisia', 'Ghana', 'Ivory Coast', 'Ghana', 'Cameroon', 'Angola',
                    'Malawi', 'Mali', 'Angola', 'Angola', 'Mali', 'Ivory Coast', 'Ghana', 'Burkina Faso',
                    'Ivory Coast', 'Burkina Faso', 'Ivory Coast', 'Egypt', 'Mozambique', 'Nigeria', 'Egypt',
                    'Egypt', 'Nigeria', 'Cameroon', 'Zambia', 'Gabon', 'Cameroon', 'Gabon', 'Cameroon', 'Angola',
                    'Ivory Coast', 'Egypt', 'Zambia', 'Ghana', 'Algeria', 'Nigeria', 'Ghana', 'Zambia',
                    'Ivory Coast', 'Gabon', 'Ghana', 'Zambia', 'Mali', 'Ghana', 'Zambia', 'Ghana', 'South Africa',
                    'Ivory Coast', 'Burkina Faso', 'Mali', 'Burkina Faso', 'Mali', 'Nigeria', 'Congo', 'Tunisia',
                    'Ghana', 'Ivory Coast', 'DR Congo', 'Ghana', 'DR Congo', 'Ivory Coast', 'Gabon', 'Burkina Faso',
                    'Gabon', 'Cameroon', 'Cameroon', 'Guinea-Bissau', 'Algeria', 'Tunisia', 'Algeria', 'Senegal',
                    'Senegal', 'Zimbabwe', 'Ivory Coast', 'DR Congo', 'Ivory Coast', 'Morocco', 'Morocco', 'Togo',
                    'Ghana', 'Mali', 'Ghana', 'Egypt', 'Egypt', 'Uganda', 'Burkina Faso', 'Senegal', 'DR Congo',
                    'Egypt', 'Burkina Faso', 'Cameroon', 'Burkina Faso', 'Egypt', 'Egypt', 'DR Congo', 'Uganda',
                    'Egypt', 'Uganda', 'Zimbabwe', 'Nigeria', 'Guinea', 'Nigeria', 'Madagascar', 'Madagascar',
                    'Burundi', 'Senegal', 'Algeria', 'Senegal', 'Kenya', 'Kenya', 'Tanzania', 'Morocco',
                    'Ivory Coast', 'Morocco', 'South Africa', 'South Africa', 'Namibia', 'Tunisia', 'Mali', 'Tunisia',
                    'Mauritania', 'Mauritania', 'Angola', 'Cameroon', 'Ghana', 'Cameroon', 'Benin', 'Benin',
                    'Guinea-Bissau', 'Morocco', 'Uganda', 'Nigeria', 'Egypt', 'Madagascar', 'Algeria', 'Mali',
                    'Ghana', 'Senegal', 'Nigeria', 'Ivory Coast', 'Madagascar', 'Senegal', 'Algeria', 'Tunisia',
                    'Senegal'])

most_frequent_value = series7.value_counts().idxmax()
series7 = series7.where(series7 == most_frequent_value, 'Other')

print("\nMost Frequent Value:")
print(most_frequent_value)
print("\nModified Series:")
print(series7)
# Out:
# Most Frequent Value:
# Ghana
#
# Modified Series:
# 0      Other
# 1      Other
# 2      Other
# 3      Other
# 4      Other
#        ...
# 617    Other
# 618    Other
# 619    Other
# 620    Other
# 621    Other
# Length: 622, dtype: object

# %%
# 1.Write a Pandas program to read the given csv file.
df = pd.read_csv('AfricaCupofNationsMatches.csv')

print(df)
# Out:
#      Year                      Date   Time      HomeTeam       AwayTeam  \
# 0    1957                  10-Feb-57    NaN       Sudan           Egypt
# 1    1957                  10-Feb-57    NaN    Ethiopia    South Africa
# 2    1957                  16-Feb-57    NaN       Egypt        Ethiopia
# 3    1959                  22-May-59    NaN        Egypt       Ethiopia
# 4    1959                  25-May-59    NaN       Sudan        Ethiopia
# ..    ...                        ...    ...          ...            ...
# 617  2019  11 July 2019 (2019-07-11)  21:00  Madagascar         Tunisia
# 618  2019  14 July 2019 (2019-07-14)  18:00     Senegal         Tunisia
# 619  2019  14 July 2019 (2019-07-14)  21:00     Algeria         Nigeria
# 620  2019  17 July 2019 (2019-07-17)  21:00     Tunisia         Nigeria
# 621  2019  19 July 2019 (2019-07-19)  21:00     Senegal         Algeria
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# ...

# %%
# 2.Write a Pandas program to get the first 7 rows of your data frame.
first_7_rows = df.head(7)
print(first_7_rows)
# Out:
#    Year      Date  Time    HomeTeam       AwayTeam  HomeTeamGoals  \
# 0  1957  10-Feb-57   NaN     Sudan           Egypt            1.0
# 1  1957  10-Feb-57   NaN  Ethiopia    South Africa            NaN
# 2  1957  16-Feb-57   NaN     Egypt        Ethiopia            4.0
# 3  1959  22-May-59   NaN      Egypt       Ethiopia            4.0
# 4  1959  25-May-59   NaN     Sudan        Ethiopia            1.0
# 5  1959  29-May-59   NaN      Egypt          Sudan            2.0
# 6  1962  14-Jan-62   NaN  Ethiopia         Tunisia            4.0
#
#    AwayTeamGoals             Stage  \
# 0            2.0        Semifinals
# 1            NaN        Semifinals
# 2            0.0             Final
# 3            0.0  Final Tournament
# 4            0.0  Final Tournament
# 5            1.0  Final Tournament
# 6            2.0        Semifinals
#
#                                 SpecialWinConditions                 Stadium  \
# ...

# %%
# 3.Write a Pandas program to select the ‘HomeTeam’, ‘AwayTeam’, ‘HomeTeamGoals’ and ‘AwayTeamGoals’ columns from your data frame.

selected_columns = df[['HomeTeam', 'AwayTeam', 'HomeTeamGoals', 'AwayTeamGoals']]
print(selected_columns)
# Out:
#         HomeTeam       AwayTeam  HomeTeamGoals  AwayTeamGoals
# 0         Sudan           Egypt            1.0            2.0
# 1      Ethiopia    South Africa            NaN            NaN
# 2         Egypt        Ethiopia            4.0            0.0
# 3          Egypt       Ethiopia            4.0            0.0
# 4         Sudan        Ethiopia            1.0            0.0
# ..           ...            ...            ...            ...
# 617  Madagascar         Tunisia            0.0            3.0
# 618     Senegal         Tunisia            1.0            0.0
# 619     Algeria         Nigeria            2.0            1.0
# 620     Tunisia         Nigeria            0.0            1.0
# 621     Senegal         Algeria            0.0            1.0
#
# [622 rows x 4 columns]

# %%
# 4.Write a Pandas program to select the rows where Egypt appears.
egypt_rows = df[(df['HomeTeam'] == 'Egypt') | (df['AwayTeam'] == 'Egypt')]
print(egypt_rows)
# Out:
#     Year      Date  Time    HomeTeam   AwayTeam  HomeTeamGoals  AwayTeamGoals  \
# 3   1959  22-May-59   NaN      Egypt   Ethiopia            4.0            0.0
# 5   1959  29-May-59   NaN      Egypt      Sudan            2.0            1.0
# 7   1962  18-Jan-62   NaN      Egypt     Uganda            2.0            1.0
# 9   1962  21-Jan-62   NaN  Ethiopia       Egypt            4.0            2.0
# 13  1963  24-Nov-63   NaN      Egypt    Nigeria            6.0            3.0
# 14  1963  26-Nov-63   NaN      Egypt      Sudan            2.0            2.0
# 16  1963  30-Nov-63   NaN      Egypt   Ethiopia            3.0            0.0
#
#                 Stage    SpecialWinConditions                 Stadium  \
# 3    Final Tournament                     NaN   Prince Farouk Stadium
# 5    Final Tournament                     NaN   Prince Farouk Stadium
# 7          Semifinals                     NaN  Hailé Sélassié Stadium
# ...

# %%
# 5.Write a Pandas program to count the number of rows and columns of your data frame.
num_rows, num_columns = df.shape
print("Number of Rows:", num_rows)
print("Number of Columns:", num_columns)
# Out:
# Number of Rows: 622
# Number of Columns: 12

# %%
# 6.Write a Pandas program to select the rows where the ‘Attendance’ is missing.
missing_attendance_rows = df[df['Attendance'].isnull()]
print(missing_attendance_rows)
# Out:
#      Year                         Date   Time        HomeTeam       AwayTeam  \
# 1    1957                     10-Feb-57    NaN      Ethiopia    South Africa
# 8    1962                     20-Jan-62    NaN       Tunisia          Uganda
# 9    1962                     21-Jan-62    NaN      Ethiopia           Egypt
# 10   1963                     24-Nov-63    NaN         Ghana         Tunisia
# 11   1963                     26-Nov-63    NaN         Ghana        Ethiopia
# ..    ...                           ...    ...            ...            ...
# 565  2017  29 January 2017 (2017-01-29)  20:00         Egypt         Morocco
# 566  2017  1 February 2017 (2017-02-01)  20:00  Burkina Faso           Egypt
# 567  2017  2 February 2017 (2017-02-02)  20:00      Cameroon           Ghana
# 568  2017  4 February 2017 (2017-02-04)  20:00  Burkina Faso           Ghana
# 569  2017  5 February 2017 (2017-02-05)  20:00         Egypt        Cameroon
#
# ...

# %%
# 6.Write a Pandas program to select the rows where the ‘Attendance’ is missing.
# Select rows where 'Attendance' is missing
missing_attendance_rows = df[df['Attendance'].isna()]
print(missing_attendance_rows)
# Out:
#      Year                         Date   Time        HomeTeam       AwayTeam  \
# 1    1957                     10-Feb-57    NaN      Ethiopia    South Africa
# 8    1962                     20-Jan-62    NaN       Tunisia          Uganda
# 9    1962                     21-Jan-62    NaN      Ethiopia           Egypt
# 10   1963                     24-Nov-63    NaN         Ghana         Tunisia
# 11   1963                     26-Nov-63    NaN         Ghana        Ethiopia
# ..    ...                           ...    ...            ...            ...
# 565  2017  29 January 2017 (2017-01-29)  20:00         Egypt         Morocco
# 566  2017  1 February 2017 (2017-02-01)  20:00  Burkina Faso           Egypt
# 567  2017  2 February 2017 (2017-02-02)  20:00      Cameroon           Ghana
# 568  2017  4 February 2017 (2017-02-04)  20:00  Burkina Faso           Ghana
# 569  2017  5 February 2017 (2017-02-05)  20:00         Egypt        Cameroon
#
# ...

# %%
# 7.Write a Pandas program to select the rows where the ‘HomeTeamGoals’ are between 3 and 6 inclusive.
goals_between_3_and_6_rows = df[df['HomeTeamGoals'].between(3, 6)]
print(goals_between_3_and_6_rows)
# Out:
#      Year                         Date   Time    HomeTeam     AwayTeam  \
# 2    1957                     16-Feb-57    NaN     Egypt      Ethiopia
# 3    1959                     22-May-59    NaN      Egypt     Ethiopia
# 6    1962                     14-Jan-62    NaN  Ethiopia       Tunisia
# 8    1962                     20-Jan-62    NaN   Tunisia        Uganda
# 9    1962                     21-Jan-62    NaN  Ethiopia         Egypt
# ..    ...                           ...    ...        ...          ...
# 553  2017  20 January 2017 (2017-01-20)  20:00   Morocco          Togo
# 585  2019     27 June 2019 (2019-06-27)  22:00     Kenya      Tanzania
# 595  2019     24 June 2019 (2019-06-24)  22:00      Mali    Mauritania
# 608  2019      6 July 2019 (2019-07-06)  18:00   Nigeria      Cameroon
# 611  2019      7 July 2019 (2019-07-07)  21:00   Algeria        Guinea
#
#      HomeTeamGoals  AwayTeamGoals              Stage    SpecialWinConditions  \
# ...

# %%
# 8.Write a Pandas program to change the “AwayTeamGoals” in the 3rd row to 10.
df.at[2, 'AwayTeamGoals'] = 10
print(df)
# Out:
#      Year                      Date   Time      HomeTeam       AwayTeam  \
# 0    1957                  10-Feb-57    NaN       Sudan           Egypt
# 1    1957                  10-Feb-57    NaN    Ethiopia    South Africa
# 2    1957                  16-Feb-57    NaN       Egypt        Ethiopia
# 3    1959                  22-May-59    NaN        Egypt       Ethiopia
# 4    1959                  25-May-59    NaN       Sudan        Ethiopia
# ..    ...                        ...    ...          ...            ...
# 617  2019  11 July 2019 (2019-07-11)  21:00  Madagascar         Tunisia
# 618  2019  14 July 2019 (2019-07-14)  18:00     Senegal         Tunisia
# 619  2019  14 July 2019 (2019-07-14)  21:00     Algeria         Nigeria
# 620  2019  17 July 2019 (2019-07-17)  21:00     Tunisia         Nigeria
# 621  2019  19 July 2019 (2019-07-19)  21:00     Senegal         Algeria
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# ...

# %%
# 9.Write a Pandas program to sort the DataFrame first by ‘HomeTeam’ in ascending order, then by ‘HomeTeamScores’ in descending order.
sorted_df = df.sort_values(['HomeTeam', 'HomeTeamGoals'], ascending=[True, False])
print(sorted_df)
# Out:
#      Year                         Date           Time    HomeTeam  \
# 205  1990                      2-Mar-90            NaN   Algeria
# 29   1968                     14-Jan-68            NaN   Algeria
# 135  1980                     16-Mar-80            NaN   Algeria
# 164  1984                      5-Mar-84            NaN   Algeria
# 171  1984                     17-Mar-84            NaN   Algeria
# ..    ...                           ...            ...        ...
# 521  2012                     12-Feb-12  20:30[note 1]    Zambia
# 549  2017  23 January 2017 (2017-01-23)          20:00  Zimbabwe
# 398  2004                     25-Jan-04          16:30  Zimbabwe
# 437  2006                     23-Jan-06          20:00  Zimbabwe
# 575  2019     30 June 2019 (2019-06-30)          21:00  Zimbabwe
#
#          AwayTeam  HomeTeamGoals  AwayTeamGoals              Stage  \
# 205       Nigeria            5.0            1.0            Group A
# ...

# %%
# 10.Write a Pandas program to get list from DataFrame column headers.
column_headers = df.columns.tolist()
print(column_headers)
# Out:
# ['Year', 'Date ', 'Time ', 'HomeTeam', 'AwayTeam', 'HomeTeamGoals', 'AwayTeamGoals', 'Stage', 'SpecialWinConditions', 'Stadium', 'City', 'Attendance']

# %%
# 11.Write a Pandas program to append a column of your choice to your DataFrame.
df['entrancefee'] = np.random.randint(10000, 20001, size=len(df))
print(df)
# Out:
#      Year                      Date   Time      HomeTeam       AwayTeam  \
# 0    1957                  10-Feb-57    NaN       Sudan           Egypt
# 1    1957                  10-Feb-57    NaN    Ethiopia    South Africa
# 2    1957                  16-Feb-57    NaN       Egypt        Ethiopia
# 3    1959                  22-May-59    NaN        Egypt       Ethiopia
# 4    1959                  25-May-59    NaN       Sudan        Ethiopia
# ..    ...                        ...    ...          ...            ...
# 617  2019  11 July 2019 (2019-07-11)  21:00  Madagascar         Tunisia
# 618  2019  14 July 2019 (2019-07-14)  18:00     Senegal         Tunisia
# 619  2019  14 July 2019 (2019-07-14)  21:00     Algeria         Nigeria
# 620  2019  17 July 2019 (2019-07-17)  21:00     Tunisia         Nigeria
# 621  2019  19 July 2019 (2019-07-19)  21:00     Senegal         Algeria
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# ...

# %%
# 12.Write a Pandas program to add 2 rows to your DataFrame.
# Create a new DataFrame with 2 rows
new_rows = pd.DataFrame({'HomeTeam': ['Brazil', 'Uganda'],
                         'AwayTeam': ['Uganda', 'Australia'],
                         'HomeTeamGoals': [1, 2],
                         'AwayTeamGoals': [3, 4],
                         'Stadium': ['Pele_e_stadio', 'Nambole'],
                         'Attendance': [10000, 20000],
                         'entrancefee':[10000, 15000]})
df = df.append(new_rows, ignore_index=True)
print(df)
# Out:
#        Year                      Date   Time    HomeTeam       AwayTeam  \
# 0    1957.0                  10-Feb-57    NaN     Sudan           Egypt
# 1    1957.0                  10-Feb-57    NaN  Ethiopia    South Africa
# 2    1957.0                  16-Feb-57    NaN     Egypt        Ethiopia
# 3    1959.0                  22-May-59    NaN      Egypt       Ethiopia
# 4    1959.0                  25-May-59    NaN     Sudan        Ethiopia
# ..      ...                        ...    ...        ...            ...
# 619  2019.0  14 July 2019 (2019-07-14)  21:00   Algeria         Nigeria
# 620  2019.0  17 July 2019 (2019-07-17)  21:00   Tunisia         Nigeria
# 621  2019.0  19 July 2019 (2019-07-19)  21:00   Senegal         Algeria
# 622     NaN                        NaN    NaN     Brazil         Uganda
# 623     NaN                        NaN    NaN     Uganda      Australia
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# ...

# %%
# 13.Write a Pandas program to change the country ‘Uganda’ to ‘China’ in the ‘AwayTeam’ column of the DataFrame.
df['AwayTeam'] = df['AwayTeam'].replace('Uganda', 'China')
print(df)

# %%
# 14.Write a Pandas program to reset index in your DataFrame.
df = df.reset_index(drop=True)
print(df)

# %%
# 15.Write a Pandas program to check whether the ‘Stadium’ column is present in your DataFrame or not.
# Check if 'Stadium' column is present in the DataFrame
if 'Stadium' in df.columns:
    print("The 'Stadium' column is present in the DataFrame.")
else:
    print("The 'Stadium' column is not present in the DataFrame.")

# %%
# 16.Write a Pandas program to convert the datatype of the ‘AwayTeamGoals’. (int to float)
df['AwayTeamGoals'] = df['AwayTeamGoals'].astype(float)

# %%
# 17.Write a Pandas program to remove the last 10 rows from your DataFrame.
df = df[:-10]

# %%
# 18.Write a Pandas program to iterate over rows in your DataFrame.
for index, row in df.iterrows():
    print(row['HomeTeam'], row['AwayTeam'], row['HomeTeamGoals'], row['AwayTeamGoals'])
# Out:
# Sudan   Egypt 1.0 2.0
# Ethiopia   South Africa nan nan
# Egypt   Ethiopia 4.0 10.0
# Egypt  Ethiopia 4.0 0.0
# Sudan   Ethiopia 1.0 0.0
# Egypt  Sudan 2.0 1.0
# Ethiopia   Tunisia 4.0 2.0
# Egypt  Uganda 2.0 1.0
# Tunisia   Uganda 3.0 0.0
# Ethiopia  Egypt 4.0 2.0
# Ghana   Tunisia 1.0 1.0
# Ghana   Ethiopia 2.0 0.0
# Ethiopia   Tunisia 4.0 2.0
# Egypt  Nigeria 6.0 3.0
# Egypt  Sudan 2.0 2.0
# Sudan   Nigeria 4.0 0.0
# Egypt  Ethiopia 3.0 0.0
# Ghana   Sudan 3.0 0.0
# Tunisia   Ethiopia 4.0 0.0
# Senegal   Tunisia 0.0 0.0
# Senegal   Ethiopia 5.0 1.0
# Ghana   Congo-Léopoldville 5.0 2.0
# Ivory Coast   Congo-Léopoldville 3.0 0.0
# Ghana   Ivory Coast 4.0 1.0
# Senegal   Ivory Coast 0.0 1.0
# Ghana   Tunisia 3.0 2.0
# Ethiopia   Uganda 2.0 1.0
# Ivory Coast   Algeria 3.0 0.0
# Ethiopia   Ivory Coast 1.0 0.0
# Algeria   Uganda 4.0 0.0
# Ivory Coast   Uganda 2.0 1.0
# Ethiopia   Algeria 3.0 1.0
# Ghana   Senegal 2.0 2.0
# Congo-Kinshasa   Congo-Brazzaville 3.0 0.0
# ...

# %%
# 19.Write a Pandas program to change the order of your DataFrame columns.
df = df[['HomeTeamGoals', 'AwayTeamGoals', 'HomeTeam', 'AwayTeam']]

# %%
# 20.Write a Pandas program to delete DataFrame row(s) whose value is 0 in the ‘HomeTeamGoals’ columns.
df = df[df['HomeTeamGoals'] != 0]
